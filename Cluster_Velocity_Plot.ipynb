# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.linspace(0, 10, 100)
y = [(1 - 0.95*((0.15+0.95)/(0.15+1)))/(1 + 0.95*((0.15+0.95)/(0.15+1)) + 2*0.15*((x*0.15)/(0.15+1)) ) for x in range(100)]
y = np.array(y)
print(len(x))
print(len(y))

fig, axes = plt.subplots(figsize=(10, 10))
plot = axes.plot(x, y)
# Out:
# 100
# 100
